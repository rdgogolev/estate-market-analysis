# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В нашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет.
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.
# **Задача:** попробуем определить основные параметры, которые влияют на рыночную стоимость объектов недвижимости.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Откроем файл с данными и изучим общую информацию.

# %%
# прочитаем датасет, выведем на экран первые 5 строк и 5 случайных строк
data = pd.read_csv('real_estate_data.csv', sep='\t') 
display(data.head(5))
display(data.sample(5))
# выведем общую информацию о датасете 
data.info()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# 1          11.0      2.0   посёлок Шушары           12817.0
# 2           8.3      0.0  Санкт-Петербург           21741.0
# 3           NaN      0.0  Санкт-Петербург           28098.0
# 4          41.0      NaN  Санкт-Петербург           31856.0
#
#   cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0             16028.0               1.0          482.0               2.0
# 1             18603.0               0.0            NaN               0.0
# 2             13933.0               1.0           90.0               2.0
# 3              6800.0               2.0           84.0               3.0
# 4              8098.0               2.0          112.0               1.0
#
#    ponds_nearest  days_exposition
# 0          755.0              NaN
# 1            NaN             81.0
# 2          574.0            558.0
# 3          234.0            424.0
# 4           48.0            121.0
#
# [5 rows x 22 columns]
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 12202             7   3075000.0       30.30  2016-12-23T00:00:00      1
# 7823             18  11900000.0       90.00  2016-06-23T00:00:00      4
# 17832            16   6799000.0       68.10  2017-10-22T00:00:00      2
# 551               8   3100000.0       31.59  2018-03-08T00:00:00      1
# 23199             6   2200000.0       28.70  2017-11-10T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 12202             NaN           5.0        15.90      3          NaN  ...
# 7823              3.0           7.0        70.00      4        False  ...
# 17832             3.3           5.0        32.00      3          NaN  ...
# 551               2.7          19.0        30.55      2          NaN  ...
# 23199             2.6           5.0        16.20      3          NaN  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 12202          5.30      NaN  Санкт-Петербург           27528.0
# 7823           9.00      0.0  Санкт-Петербург           11599.0
# 17832         20.00      NaN  Санкт-Петербург           20516.0
# 551            9.28      2.0   посёлок Мурино               NaN
# 23199          5.40      1.0     село Павлово               NaN
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 12202              9415.0               0.0            NaN               1.0
# 7823               9356.0               1.0          503.0               3.0
# 17832              4871.0               1.0          585.0               3.0
# 551                   NaN               NaN            NaN               NaN
# 23199                 NaN               NaN            NaN               NaN
#
#        ponds_nearest  days_exposition
# 12202          711.0            396.0
# 7823           552.0             32.0
# 17832          576.0            334.0
# 551              NaN             70.0
# 23199            NaN            518.0
#
# [5 rows x 22 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
#  15  airports_nearest      18157 non-null  float64
#  16  cityCenters_nearest   18180 non-null  float64
#  17  parks_around3000      18181 non-null  float64
#  18  parks_nearest         8079 non-null   float64
#  19  ponds_around3000      18181 non-null  float64
#  20  ponds_nearest         9110 non-null   float64
#  21  days_exposition       20518 non-null  float64
# dtypes: bool(2), float64(14), int64(3), object(3)
# memory usage: 3.7+ MB

# %%
# переименуем названия столбца с расстоянием до центра города, избавимся от CamelCase 
data = data.rename(columns= {'cityCenters_nearest': 'city_centers_nearest'})
data.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'city_centers_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# ## 2. Предобработка данных

# %% [markdown]
# В рамках предобработки данных рассмотрим столбцы на предмет правильности типа данных, наличия пропусков, редких и выбивающихся значений.

# %% [markdown]
# Для начала убедимся в отсутствии явных дубликатов в датасете.

# %%
print(f'Количество дубликатов в датасете: {data.duplicated().sum()}')
# Out:
# Количество дубликатов в датасете: 0

# %% [markdown]
# Основная цель исследования - **научиться определять рыночную цену** квартир на основании различных параметров объекта. Показатель рыночной цены может исказиться из-за аномально высоких и редких квартир.
# Для этого определим с помощью столбца `last_price`, какие цены квартир являются аномально высокими и создадим отдельный датафрейм без таких объектов.

# %%
sns.histplot(data=data['last_price'], bins=100)
plt.ylabel('Кол-во объявлений')
plt.xlabel('Цена продажи объекта')
plt.title('Распределение объектов по цене продажи');

# %% [markdown]
# Гистограмма растянулась до стоимости 800 млн рублей., при этом уже на отметке 50 млн рублей не видно значений. Исключим значения выше 50 млн рублей. Построим новую гистограмму, а также "ящик с усами".

# %%
sns.histplot(data=data.query('last_price < 50000000')['last_price'], bins=100)
plt.ylabel('Кол-во объявлений')
plt.xlabel('Цена продажи объекта')
plt.title('Распределение объектов по цене продажи');

# %% [markdown]
# Квартиры со стоимостью выше 40 млн рублей практически не видны на гистограмме. Сохраним в переменную data2 значения ниже 40 млн рублей для дальнейшего анализа.

# %%
data2 = data.query('last_price < 50000000')

# %% [markdown]
# Столбец `first_day_exposition` содержит дату публикации, при этом тип данных - object. Переведём данные в формат datetime, а также уберём часы, минуты, секунды, которые показывают нулевые значения.

# %%
data2['first_day_exposition'] = pd.to_datetime(data2['first_day_exposition'])
data2['first_day_exposition'] = data2['first_day_exposition'].dt.round('D')
data2.sample(5)
# Out:
# C:\Users\Рома\AppData\Local\Temp\ipykernel_14812\2466148775.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['first_day_exposition'] = pd.to_datetime(data2['first_day_exposition'])
# C:\Users\Рома\AppData\Local\Temp\ipykernel_14812\2466148775.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['first_day_exposition'] = data2['first_day_exposition'].dt.round('D')
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 2984              2   4238000.0       39.60           2019-03-04      1
# 672               1   4400000.0       36.00           2019-02-26      1
# 11973            10   1050000.0       44.80           2019-04-10      2
# 1434              4   4950000.0       56.00           2018-09-26      3
# 7100              1   3200000.0       34.58           2016-03-22      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 2984             2.60          19.0         19.4      2          NaN  ...
# 672              2.70          26.0         15.0     14        False  ...
# 11973            2.55           4.0         28.0      4          NaN  ...
# 1434             2.50           5.0         41.0      2          NaN  ...
# 7100              NaN          17.0         16.0     11          NaN  ...
#
#        kitchen_area  balcony                  locality_name  airports_nearest  \
# 2984           10.1      NaN                Санкт-Петербург           35913.0
# 672            13.0      2.0              посёлок Парголово           54029.0
# 11973           8.0      1.0  городской посёлок Лесогорский               NaN
# 1434            5.4      NaN                     Сестрорецк           58223.0
# 7100            9.6      0.0                деревня Кудрово               NaN
#
#       city_centers_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 2984               12387.0               2.0          181.0               2.0
# 672                20206.0               0.0            NaN               0.0
# 11973                  NaN               NaN            NaN               NaN
# 1434               35152.0               1.0          531.0               2.0
# 7100                   NaN               NaN            NaN               NaN
#
#        ponds_nearest  days_exposition
# 2984           233.0             10.0
# 672              NaN             48.0
# 11973            NaN              NaN
# 1434           192.0              NaN
# 7100             NaN            315.0
#
# [5 rows x 22 columns]

# %% [markdown]
# Столбцы `ceiling_height`, `floors_total`, `living_area`, `kitchen_area` содержат пропуски. Вероятнее всего, пользователи оставили эти поля пустыми, так как не знают данные параметры про квартиру, либо случайно пропустили.

# %% [markdown]
# Пропуски в столбцах `living_area`, `kitchen_area` можно заполнить медианным значением. Медианные значения жилой площади и площади кухни можно вычислить через соотношение общей площади конкретной квартиры к медианной площади жилой/кухни.
# Сделаем следующие шаги:
# 1) Посчитаем по столбцу соотношение медианы общей площади к медиане площади кухни/ жилой площади;
# 2) Заполним пропуски в столбце с площадью кухни делением общей площади этого объекта на найденное соотношение;
# 3) Повторим шаг 2 для жилой площади.

# %%
living_area_ratio = data2['total_area'].median() / data2['living_area'].median()
kitchen_area_ratio = data2['total_area'].median() / data2['kitchen_area'].median()
living_area_ratio, kitchen_area_ratio
# Out:
# (1.7333333333333334, 5.714285714285714)

# %%
data2['kitchen_area'] = data2['kitchen_area'].fillna(data2['total_area'] / kitchen_area_ratio)
# Out:
# C:\Users\Рома\AppData\Local\Temp\ipykernel_14812\3411266444.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['kitchen_area'] = data2['kitchen_area'].fillna(data2['total_area'] / kitchen_area_ratio)

# %%
data2['living_area'] = data2['living_area'].fillna(data2['total_area'] / living_area_ratio)
# Out:
# C:\Users\Рома\AppData\Local\Temp\ipykernel_14812\3523570901.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['living_area'] = data2['living_area'].fillna(data2['total_area'] / living_area_ratio)

# %%
data2.head(20)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00           2019-03-07      3
# 1              7   3350000.0       40.40           2018-12-04      1
# 2             10   5196000.0       56.00           2015-08-20      2
# 4              2  10000000.0      100.00           2018-06-19      2
# 5             10   2890000.0       30.40           2018-09-10      1
# 6              6   3700000.0       37.30           2017-11-02      1
# 7              5   7915000.0       71.60           2019-04-18      2
# 8             20   2900000.0       33.16           2018-05-23      1
# 9             18   5400000.0       61.00           2017-02-26      3
# 10             5   5050000.0       39.60           2017-11-16      1
# 11             9   3300000.0       44.00           2018-08-27      2
# 12            10   3890000.0       54.00           2016-06-30      2
# 13            20   3550000.0       42.80           2017-07-01      2
# 14             1   4400000.0       36.00           2016-06-23      1
# 15            16   4650000.0       39.00           2017-11-18      1
# 16            11   6700000.0       82.00           2017-11-23      3
# 17             6   4180000.0       36.00           2016-09-09      1
# 18             8   3250000.0       31.00           2017-01-27      1
# 19            16  14200000.0      121.00           2019-01-09      3
# 20            12   6120000.0       80.00           2017-09-28      3
#
#     ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0             2.70          16.0    51.000000      8          NaN  ...
# 1              NaN          11.0    18.600000      1          NaN  ...
# 2              NaN           5.0    34.300000      4          NaN  ...
# 4             3.03          14.0    32.000000     13          NaN  ...
# 5              NaN          12.0    14.400000      5          NaN  ...
# 6              NaN          26.0    10.600000      6          NaN  ...
# 7              NaN          24.0    41.307692     22          NaN  ...
# 8              NaN          27.0    15.430000     26          NaN  ...
# 9             2.50           9.0    43.600000      7          NaN  ...
# 10            2.67          12.0    20.300000      3          NaN  ...
# 11             NaN           5.0    31.000000      4        False  ...
# 12             NaN           5.0    30.000000      5          NaN  ...
# 13            2.56           5.0    27.000000      5          NaN  ...
# 14             NaN           6.0    17.000000      1          NaN  ...
# 15             NaN          14.0    20.500000      5          NaN  ...
# 16            3.05           5.0    55.600000      1          NaN  ...
# 17             NaN          17.0    16.500000      7          NaN  ...
# 18            2.50           5.0    19.400000      2          NaN  ...
# 19            2.75          16.0    76.000000      8          NaN  ...
# 20            2.70          27.0    48.000000     11          NaN  ...
#
#     kitchen_area  balcony              locality_name  airports_nearest  \
# 0          25.00      NaN            Санкт-Петербург           18863.0
# 1          11.00      2.0             посёлок Шушары           12817.0
# 2           8.30      0.0            Санкт-Петербург           21741.0
# 4          41.00      NaN            Санкт-Петербург           31856.0
# 5           9.10      NaN  городской посёлок Янино-1               NaN
# 6          14.40      1.0          посёлок Парголово           52996.0
# 7          18.90      2.0            Санкт-Петербург           23982.0
# 8           8.81      NaN             посёлок Мурино               NaN
# 9           6.50      2.0            Санкт-Петербург           50898.0
# 10          8.50      NaN            Санкт-Петербург           38357.0
# 11          6.00      1.0                  Ломоносов           48252.0
# 12          9.00      0.0                  Сертолово               NaN
# 13          5.20      1.0                   Петергоф           37868.0
# 14          8.00      0.0                     Пушкин           20782.0
# 15          7.60      1.0            Санкт-Петербург           12900.0
# 16          9.00      NaN            Санкт-Петербург           22108.0
# 17         11.00      1.0            Санкт-Петербург           33564.0
# 18          5.60      1.0            Санкт-Петербург           44060.0
# 19         12.00      NaN            Санкт-Петербург           38900.0
# 20         12.00      2.0          посёлок Парголово           53134.0
#
#    city_centers_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0               16028.0               1.0          482.0               2.0
# 1               18603.0               0.0            NaN               0.0
# 2               13933.0               1.0           90.0               2.0
# 4                8098.0               2.0          112.0               1.0
# 5                   NaN               NaN            NaN               NaN
# 6               19143.0               0.0            NaN               0.0
# 7               11634.0               0.0            NaN               0.0
# 8                   NaN               NaN            NaN               NaN
# 9               15008.0               0.0            NaN               0.0
# 10              13878.0               1.0          310.0               2.0
# 11              51677.0               0.0            NaN               0.0
# 12                  NaN               NaN            NaN               NaN
# 13              33058.0               1.0          294.0               3.0
# 14              30759.0               0.0            NaN               1.0
# 15              14259.0               1.0          590.0               1.0
# 16              10698.0               3.0          420.0               0.0
# 17              14616.0               0.0            NaN               1.0
# 18              10842.0               1.0          759.0               0.0
# 19              12843.0               0.0            NaN               0.0
# 20              19311.0               0.0            NaN               0.0
#
#     ponds_nearest  days_exposition
# 0           755.0              NaN
# 1             NaN             81.0
# 2           574.0            558.0
# 4            48.0            121.0
# 5             NaN             55.0
# 6             NaN            155.0
# 7             NaN              NaN
# 8             NaN            189.0
# 9             NaN            289.0
# 10          553.0            137.0
# 11            NaN              7.0
# 12            NaN             90.0
# 13          298.0            366.0
# 14           96.0            203.0
# 15          296.0             19.0
# 16            NaN            397.0
# 17          859.0            571.0
# 18            NaN            168.0
# 19            NaN             97.0
# 20            NaN             74.0
#
# [20 rows x 22 columns]

# %% [markdown]
# Рассмотрим уникальные значения столбца `ceiling_height`.

# %%
data2['ceiling_height'].sort_values().unique()
# Out:
# array([  1.  ,   1.2 ,   1.75,   2.  ,   2.2 ,   2.25,   2.3 ,   2.34,
#          2.4 ,   2.45,   2.46,   2.47,   2.48,   2.49,   2.5 ,   2.51,
#          2.52,   2.53,   2.54,   2.55,   2.56,   2.57,   2.58,   2.59,
#          2.6 ,   2.61,   2.62,   2.63,   2.64,   2.65,   2.66,   2.67,
#          2.68,   2.69,   2.7 ,   2.71,   2.72,   2.73,   2.74,   2.75,
#          2.76,   2.77,   2.78,   2.79,   2.8 ,   2.81,   2.82,   2.83,
#          2.84,   2.85,   2.86,   2.87,   2.88,   2.89,   2.9 ,   2.91,
#          2.92,   2.93,   2.94,   2.95,   2.96,   2.97,   2.98,   2.99,
#          3.  ,   3.01,   3.02,   3.03,   3.04,   3.05,   3.06,   3.07,
#          3.08,   3.09,   3.1 ,   3.11,   3.12,   3.13,   3.14,   3.15,
#          3.16,   3.17,   3.18,   3.2 ,   3.21,   3.22,   3.23,   3.24,
#          3.25,   3.26,   3.27,   3.28,   3.29,   3.3 ,   3.31,   3.32,
#          3.33,   3.34,   3.35,   3.36,   3.37,   3.38,   3.39,   3.4 ,
#          3.42,   3.43,   3.44,   3.45,   3.46,   3.47,   3.48,   3.49,
#          3.5 ,   3.51,   3.52,   3.53,   3.54,   3.55,   3.56,   3.57,
#          3.58,   3.59,   3.6 ,   3.62,   3.63,   3.65,   3.66,   3.67,
#          3.68,   3.69,   3.7 ,   3.75,   3.78,   3.8 ,   3.83,   3.84,
#          3.85,   3.86,   3.87,   3.88,   3.9 ,   3.93,   3.95,   3.98,
#          4.  ,   4.06,   4.1 ,   4.14,   4.15,   4.19,   4.2 ,   4.25,
#          4.3 ,   4.37,   4.4 ,   4.45,   4.5 ,   4.7 ,   4.8 ,   5.  ,
#          5.3 ,   5.5 ,   5.8 ,   8.  ,   8.3 ,  10.3 ,  14.  ,  20.  ,
#         22.6 ,  24.  ,  25.  ,  26.  ,  27.  ,  27.5 ,  32.  , 100.  ,
#           nan])

# %% [markdown]
# Исключим квартиры с высотой потолков 2 м и меньше. Такая низкая неудобная высота потолков нехарактерна для российских квартир.

# %%
data2 = data2.query('ceiling_height > 2')

# %% [markdown]
# Несколько значений, вероятнее всего, были записаны неверно: например, вместо 24 м, пользователь имел в виду высоту 2,4 м. Заменим подобные аномальные значения.

# %%
data2.update(data2[(data2['ceiling_height'] >= 20) & (data2['ceiling_height'] <= 36)]['ceiling_height']/10)

# %% [markdown]
# А пропуски в столбце заполним медианой.

# %%
data2['ceiling_height'] = data2['ceiling_height'].fillna(data2['ceiling_height'].median())

# %% [markdown]
# Отдельно рассмотрим квартиры с аномально высокой высотой потолком (больше 5 м).

# %%
data2.sort_values('ceiling_height').query('ceiling_height > 5')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 12628            14   3900000.0        50.0           2018-03-29      1
# 7578             17  38000000.0       143.0           2017-11-02      3
# 21227             0   8200000.0        71.0           2017-07-21      0
# 15743            14   5600000.0        67.0           2016-11-11      3
# 17442             0   5350000.0        54.0           2015-06-16      2
# 3474              3   1400000.0        30.0           2018-03-16      1
# 5863             20   5650000.0        45.0           2018-08-15      1
# 22309            20   5300000.0        45.0           2017-09-30      1
# 15061            19   5600000.0        56.4           2018-05-11      2
# 22869             0  15000000.0        25.0           2018-07-25      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 12628             5.3           5.0    28.846154      5          NaN  ...
# 7578              5.5           5.0    83.000000      5          NaN  ...
# 21227             5.8           5.0    68.000000      5          NaN  ...
# 15743             8.0          16.0    41.000000      1          NaN  ...
# 17442             8.0           5.0    29.000000      2          NaN  ...
# 3474              8.0           5.0    15.300000      2        False  ...
# 5863              8.3          16.0    19.300000     14          NaN  ...
# 22309            10.3          16.0    15.500000     15          NaN  ...
# 15061            14.0          14.0    32.400000      5          NaN  ...
# 22869           100.0           5.0    14.000000      5         True  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 12628         8.750      NaN  Санкт-Петербург           19644.0
# 7578         29.000      1.0  Санкт-Петербург           26333.0
# 21227        12.425      0.0  Санкт-Петербург           20170.0
# 15743         8.000      NaN  Санкт-Петербург           32691.0
# 17442         9.450      1.0     Красное Село           24638.0
# 3474          7.300      NaN    деревня Нурма               NaN
# 5863          8.300      1.0  Санкт-Петербург           13069.0
# 22309         7.875      NaN  Санкт-Петербург           36353.0
# 15061         9.100      2.0  Санкт-Петербург           14814.0
# 22869        11.000      5.0  Санкт-Петербург           34963.0
#
#       city_centers_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 12628               3918.0               1.0          505.0               1.0
# 7578                6448.0               3.0          479.0               0.0
# 21227               1261.0               2.0          295.0               3.0
# 15743              11035.0               1.0          723.0               0.0
# 17442              28062.0               0.0            NaN               0.0
# 3474                   NaN               NaN            NaN               NaN
# 5863               10763.0               0.0            NaN               1.0
# 22309              11936.0               2.0          440.0               2.0
# 15061              13610.0               0.0            NaN               0.0
# 22869               8283.0               1.0          223.0               3.0
#
#        ponds_nearest  days_exposition
# 12628           92.0              8.0
# 7578             NaN              NaN
# 21227          366.0             30.0
# 15743            NaN            474.0
# 17442            NaN            469.0
# 3474             NaN            125.0
# 5863           613.0             14.0
# 22309          450.0            136.0
# 15061            NaN            315.0
# 22869           30.0             19.0
#
# [10 rows x 22 columns]

# %% [markdown]
# Последняя квартира - апартмены площадью 25 кв. м. с 5 балконами и высотой потолков в 100 м, проданной за 15 млн рублей - очень странные характеристики квартиры, поэтому исключим эту квартиру из выборки.

# %%
data2 = data2.query('ceiling_height < 100')

# %% [markdown]
# Данные столбца `is_apartment` должны иметь булев тип, однако информация по датасету показывает формат object и небольшое количество заполненных значений. Выведем уникальные значения из столбца.

# %%
data2['is_apartment'].unique()
# Out:
# array([nan, False, True], dtype=object)

# %% [markdown]
# Здесь могут быть две причины появления пропусков:
# 1) пользователь не знает, какое именно жилье является апартаментами, и поэтому оставил поле пустым;
# 2) квартира не является апартаментами и пользователь оставил это поле пустым.
#
# Проверить эти гипотезы невозможно, поэтому оставим пропуски в данном столбце.

# %% [markdown]
# Пропуск в столбце `balcony` означает, скорее всего, что балконов в квартире нет. Такие пропуски правильно заменить на 0.

# %%
data2['balcony'] = data2['balcony'].fillna('0')

# %% [markdown]
# Столбец `locality_name` содержит название населенного пункта. Пропуск в столбце locality_name правильно заменить на 'не указано', так у нас нет этой информации.

# %%
data2['locality_name'] = data2['locality_name'].fillna('не указано')

# %% [markdown]
# Рассмотрим также данные в этом столбце на наличие неявных дубликатов.

# %%
print(data2['locality_name'].nunique())
data2['locality_name'].sort_values().unique()
# Out:
# 284
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалёво',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'городской поселок Большая Ижора', 'городской поселок Янино-1',
#        'городской посёлок Будогощь', 'городской посёлок Виллози',
#        'городской посёлок Лесогорский', 'городской посёлок Мга',
#        'городской посёлок Назия', 'городской посёлок Новоселье',
#        'городской посёлок Павлово', 'городской посёлок Рощино',
#        'городской посёлок Свирьстрой', 'городской посёлок Советский',
#        'городской посёлок Фёдоровское', 'городской посёлок Янино-1',
#        'деревня Агалатово', 'деревня Батово', 'деревня Бегуницы',
#        'деревня Белогорка', 'деревня Большая Вруда',
#        'деревня Большая Пустомержа', 'деревня Большие Колпаны',
#        'деревня Бор', 'деревня Борисова Грива', 'деревня Ваганово',
#        'деревня Вартемяги', 'деревня Вахнова Кара', 'деревня Гарболово',
#        'деревня Глинка', 'деревня Горбунки', 'деревня Гостилицы',
#        'деревня Заневка', 'деревня Зимитицы', 'деревня Извара',
#        'деревня Калитино', 'деревня Кальтино', 'деревня Камышовка',
#        'деревня Каськово', 'деревня Келози', 'деревня Кипень',
#        'деревня Кисельня', 'деревня Колтуши', 'деревня Коркино',
#        'деревня Котлы', 'деревня Кривко', 'деревня Кудрово',
#        'деревня Кузьмолово', 'деревня Куттузи', 'деревня Лаголово',
#        'деревня Лампово', 'деревня Лесколово', 'деревня Лопухинка',
#        'деревня Малое Верево', 'деревня Малое Карлино',
#        'деревня Малые Колпаны', 'деревня Меньково', 'деревня Мины',
#        'деревня Мистолово', 'деревня Ненимяки', 'деревня Нижняя',
#        'деревня Низино', 'деревня Новое Девяткино', 'деревня Новолисино',
#        'деревня Нурма', 'деревня Оржицы', 'деревня Парицы',
#        'деревня Пеники', 'деревня Пудомяги', 'деревня Рабитицы',
#        'деревня Разбегаево', 'деревня Разметелево', 'деревня Рапполово',
#        'деревня Старая', 'деревня Старая Пустошь',
#        'деревня Старосиверская', 'деревня Суоранда', 'деревня Сяськелево',
#        'деревня Тарасово', 'деревня Тойворово', 'деревня Торосово',
#        'деревня Фалилеево', 'деревня Фёдоровское', 'деревня Хапо-Ое',
#        'деревня Хязельки', 'деревня Шпаньково', 'деревня Юкки',
#        'деревня Ялгино', 'деревня Яльгелево',
#        'коттеджный поселок Кивеннапа Север', 'коттеджный поселок Счастье',
#        'не указано', 'поселок Аннино', 'поселок Барышево',
#        'поселок Бугры', 'поселок Возрождение', 'поселок Войсковицы',
#        'поселок Гарболово', 'поселок Гладкое', 'поселок Глажево',
#        'поселок Глебычево', 'поселок Гончарово', 'поселок Громово',
#        'поселок Дружноселье', 'поселок Елизаветино', 'поселок Жилпосёлок',
#        'поселок Житково', 'поселок Заводской', 'поселок Запорожское',
#        'поселок Зимитицы', 'поселок Ильичёво', 'поселок Кингисеппский',
#        'поселок Кобралово', 'поселок Коммунары', 'поселок Коробицыно',
#        'поселок Котельский', 'поселок Красная Долина', 'поселок Лесное',
#        'поселок Лисий Нос', 'поселок Лукаши', 'поселок Любань',
#        'поселок Мельниково', 'поселок Мичуринское', 'поселок Молодцово',
#        'поселок Мурино', 'поселок Новый Свет', 'поселок Новый Учхоз',
#        'поселок Оредеж', 'поселок Пансионат Зелёный Бор',
#        'поселок Первомайское', 'поселок Перово', 'поселок Петровское',
#        'поселок Победа', 'поселок Поляны', 'поселок Почап',
#        'поселок Починок', 'поселок Пушное', 'поселок Рабитицы',
#        'поселок Романовка', 'поселок Ромашки', 'поселок Рябово',
#        'поселок Сельцо', 'поселок Семрино', 'поселок Серебрянский',
#        'поселок Совхозный', 'поселок Стеклянный', 'поселок Сумино',
#        'поселок Суходолье', 'поселок Тельмана', 'поселок Терволово',
#        'поселок Торковичи', 'поселок Углово', 'поселок Ушаки',
#        'поселок Цвелодубово', 'поселок городского типа Вырица',
#        'поселок городского типа Дружная Горка',
#        'поселок городского типа Дубровка',
#        'поселок городского типа Ефимовский',
#        'поселок городского типа Кондратьево',
#        'поселок городского типа Красный Бор',
#        'поселок городского типа Кузьмоловский',
#        'поселок городского типа Лебяжье',
#        'поселок городского типа Никольский',
#        'поселок городского типа Приладожский',
#        'поселок городского типа Рахья', 'поселок городского типа Рощино',
#        'поселок городского типа Синявино',
#        'поселок городского типа Советский',
#        'поселок городского типа имени Свердлова',
#        'поселок станции Вещево', 'поселок станции Приветнинское',
#        'посёлок Александровская', 'посёлок Аннино', 'посёлок Бугры',
#        'посёлок Возрождение', 'посёлок Войскорово', 'посёлок Гаврилово',
#        'посёлок Дзержинского', 'посёлок Жилгородок', 'посёлок Ильичёво',
#        'посёлок Кикерино', 'посёлок Кобралово', 'посёлок Коробицыно',
#        'посёлок Ленинское', 'посёлок Лисий Нос', 'посёлок Мельниково',
#        'посёлок Металлострой', 'посёлок Мичуринское',
#        'посёлок Молодёжное', 'посёлок Мурино', 'посёлок Новогорелово',
#        'посёлок Новый Свет', 'посёлок Парголово', 'посёлок Песочный',
#        'посёлок Петровское', 'посёлок Платформа 69-й километр',
#        'посёлок Плодовое', 'посёлок Победа', 'посёлок Поляны',
#        'посёлок Понтонный', 'посёлок Пригородный', 'посёлок Пудость',
#        'посёлок Репино', 'посёлок Ропша', 'посёлок Сапёрное',
#        'посёлок Сапёрный', 'посёлок Сосново', 'посёлок Старая Малукса',
#        'посёлок Стеклянный', 'посёлок Стрельна', 'посёлок Суйда',
#        'посёлок Сумино', 'посёлок Тельмана', 'посёлок Терволово',
#        'посёлок Торфяное', 'посёлок Шушары', 'посёлок Щеглово',
#        'посёлок городского типа Важины', 'посёлок городского типа Вырица',
#        'посёлок городского типа Красный Бор',
#        'посёлок городского типа Кузнечное',
#        'посёлок городского типа Кузьмоловский',
#        'посёлок городского типа Лебяжье', 'посёлок городского типа Мга',
#        'посёлок городского типа Павлово',
#        'посёлок городского типа Рощино', 'посёлок городского типа Рябово',
#        'посёлок городского типа Сиверский',
#        'посёлок городского типа Тайцы', 'посёлок городского типа Токсово',
#        'посёлок городского типа Ульяновка',
#        'посёлок городского типа Форносово',
#        'посёлок городского типа имени Морозова',
#        'посёлок городского типа имени Свердлова',
#        'посёлок при железнодорожной станции Вещево',
#        'посёлок при железнодорожной станции Приветнинское',
#        'посёлок станции Громово', 'садовое товарищество Новая Ропша',
#        'садовое товарищество Рахья', 'село Копорье', 'село Павлово',
#        'село Путилово', 'село Русско-Высоцкое'], dtype=object)

# %% [markdown]
# Названия некоторых населённых пунктов записаны по-разному. Необходимо устранить такие дубликаты. Для этого сделаем следующие шаги:
# 1. Уберём букву "ё" из названий населённых пунктов;
# 2. Поменяем словосочетания "поселок городского типа", "городской поселок" на слово "поселок".
# 3. Исключим из названия населённых пунктов слова "поселок" и "деревня", так как некоторые населённые пункты повторяются без указания на его вид (Например, Кудрово до 2018 года был деревней, однако потом стал городом).

# %%
data2['locality_name'] = data2['locality_name'].str.replace('ё', 'е')
data2['locality_name'] = data2['locality_name'].str.replace('городской поселок', 'поселок')
data2['locality_name'] = data2['locality_name'].str.replace('поселок городского типа', 'поселок')
data2['locality_name'] = data2['locality_name'].str.replace('поселок ', '')
data2['locality_name'] = data2['locality_name'].str.replace('деревня ', '')

data2['locality_name'].nunique()
# Out:
# 247

# %% [markdown]
# У нас получилось сократить количество уникальных названий населённых пунктов с 284 до 247.

# %% [markdown]
# Теперь рассмотрим столбцы данных, в которых данные получены автоматически на основе картографических данных: `airports_nearest`, `city_centers_nearest`, `parks_around3000`, `parks_nearest`, `ponds_around3000`, `ponds_nearest`.

# %% [markdown]
# Пропуски в указанных столбцах могут означать, что система не смогла составить маршрут до аэропорта/центра города/водоёма/парка. Возможная причина - существенная дальность недвижимости до этих объектов.

# %% [markdown]
# Пропуски есть также в столбце `days_exposition`. Вероятнее всего, пропуски в этом столбце означают, что на момент выгрузки датасета объявления ещё актуальными. Оставим пропуски в данном столбце.

# %% [markdown]
# Так как мы удаляли некоторые строки, установим порядок индексов заново.

# %%
data2 = data2.reset_index(drop=True)
data2.head(5)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             2  10000000.0       100.0           2018-06-19      2
# 2            18   5400000.0        61.0           2017-02-26      3
# 3             5   5050000.0        39.6           2017-11-16      1
# 4            20   3550000.0        42.8           2017-07-01      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1            3.03          14.0         32.0     13          NaN  ...
# 2            2.50           9.0         43.6      7          NaN  ...
# 3            2.67          12.0         20.3      3          NaN  ...
# 4            2.56           5.0         27.0      5          NaN  ...
#
#    kitchen_area  balcony    locality_name airports_nearest  \
# 0          25.0        0  Санкт-Петербург          18863.0
# 1          41.0        0  Санкт-Петербург          31856.0
# 2           6.5      2.0  Санкт-Петербург          50898.0
# 3           8.5        0  Санкт-Петербург          38357.0
# 4           5.2      1.0         Петергоф          37868.0
#
#   city_centers_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0              16028.0               1.0          482.0               2.0
# 1               8098.0               2.0          112.0               1.0
# 2              15008.0               0.0            NaN               0.0
# 3              13878.0               1.0          310.0               2.0
# 4              33058.0               1.0          294.0               3.0
#
#    ponds_nearest  days_exposition
# 0          755.0              NaN
# 1           48.0            121.0
# 2            NaN            289.0
# 3          553.0            137.0
# 4          298.0            366.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ## 3. Добавление новых столбцов

# %% [markdown]
# Для дальнейшего исследования нам понадобятся новые столбца с данными, посчитанными из имеющихся столбцов.

# %% [markdown]
# Цена одного квадратного метра

# %%
data2['price_per_m'] = round(data2['last_price'] / data2['total_area'], 2)

# %% [markdown]
# День недели публикации объявления (0 — понедельник, 1 — вторник и так далее)

# %%
data2['day_of_week'] = data2['first_day_exposition'].dt.dayofweek

# %% [markdown]
# Месяц публикации объявления

# %%
data2['first_day_exposition_month'] = pd.DatetimeIndex(data2['first_day_exposition']).month

# %% [markdown]
# Год публикации объявления

# %%
data2['first_day_exposition_year'] = pd.DatetimeIndex(data2['first_day_exposition']).year

# %% [markdown]
# Тип этажа квартиры (значения — «первый», «последний», «другой»)

# %%
data2['floor_type'] = 'другой'
for floor_each in range(len(data2)) :
    if data2['floor'][floor_each] == 1 :
        data2['floor_type'][floor_each] = 'первый'
    elif data2['floor'][floor_each] == data2['floors_total'][floor_each] :
        data2['floor_type'][floor_each] = 'последний'
# Out:
# C:\Users\Рома\AppData\Local\Temp\ipykernel_14812\4194486733.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['floor_type'][floor_each] = 'последний'
# C:\Users\Рома\AppData\Local\Temp\ipykernel_14812\4194486733.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['floor_type'][floor_each] = 'первый'

# %% [markdown]
# Расстояние до центра города в километрах (перевдем из м в км и округлим до целых значений).

# %%
data2['city_centers_nearest_km'] = round(data2['city_centers_nearest'] / 1000)

# %%
data2.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             2  10000000.0       100.0           2018-06-19      2
# 2            18   5400000.0        61.0           2017-02-26      3
# 3             5   5050000.0        39.6           2017-11-16      1
# 4            20   3550000.0        42.8           2017-07-01      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1            3.03          14.0         32.0     13          NaN  ...
# 2            2.50           9.0         43.6      7          NaN  ...
# 3            2.67          12.0         20.3      3          NaN  ...
# 4            2.56           5.0         27.0      5          NaN  ...
#
#    parks_nearest  ponds_around3000  ponds_nearest days_exposition price_per_m  \
# 0          482.0               2.0          755.0             NaN   120370.37
# 1          112.0               1.0           48.0           121.0   100000.00
# 2            NaN               0.0            NaN           289.0    88524.59
# 3          310.0               2.0          553.0           137.0   127525.25
# 4          294.0               3.0          298.0           366.0    82943.93
#
#    day_of_week  first_day_exposition_month  first_day_exposition_year  \
# 0            3                           3                       2019
# 1            1                           6                       2018
# 2            6                           2                       2017
# 3            3                          11                       2017
# 4            5                           7                       2017
#
#    floor_type  city_centers_nearest_km
# 0      другой                     16.0
# 1      другой                      8.0
# 2      другой                     15.0
# 3      другой                     14.0
# 4   последний                     33.0
#
# [5 rows x 28 columns]

# %% [markdown]
# ## 4.  Исследовательский анализ данных

# %% [markdown]
# После предобработки и добавления новых столбцов датасет был существенно изменён. Выведем общую информацию о датасете заново

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14399 entries, 0 to 14398
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   total_images                14399 non-null  int64
#  1   last_price                  14399 non-null  float64
#  2   total_area                  14399 non-null  float64
#  3   first_day_exposition        14399 non-null  datetime64[ns]
#  4   rooms                       14399 non-null  int64
#  5   ceiling_height              14399 non-null  float64
#  6   floors_total                14390 non-null  float64
#  7   living_area                 14399 non-null  float64
#  8   floor                       14399 non-null  int64
#  9   is_apartment                1849 non-null   object
#  10  studio                      14399 non-null  bool
#  11  open_plan                   14399 non-null  bool
#  12  kitchen_area                14399 non-null  float64
#  13  balcony                     14399 non-null  object
#  14  locality_name               14399 non-null  object
#  15  airports_nearest            11448 non-null  float64
#  16  city_centers_nearest        11466 non-null  float64
#  17  parks_around3000            11467 non-null  float64
#  18  parks_nearest               5219 non-null   float64
#  19  ponds_around3000            11467 non-null  float64
#  20  ponds_nearest               5653 non-null   float64
#  21  days_exposition             11968 non-null  float64
#  22  price_per_m                 14399 non-null  float64
#  23  day_of_week                 14399 non-null  int64
#  24  first_day_exposition_month  14399 non-null  int64
#  25  first_day_exposition_year   14399 non-null  int64
#  26  floor_type                  14399 non-null  object
#  27  city_centers_nearest_km     11466 non-null  float64
# dtypes: bool(2), datetime64[ns](1), float64(15), int64(6), object(4)
# memory usage: 2.9+ MB

# %%
print(f'От изначального датасета осталось {round(len(range(data2.shape[0])) / len(range(data.shape[0])), 2)}% объявлений')
# Out:
# От изначального датасета осталось 0.61% объявлений

# %% [markdown]
# ### 4.1. Построим гистограммы для следующих параметров:
# - общая площадь;
# - жилая площадь;
# - площадь кухни;
# - цена объекта;
# - количество комнат;
# - высота потолков;
# - этаж квартиры;
# - тип этажа квартиры («первый», «последний», «другой»);
# - общее количество этажей в доме;
# - расстояние до центра города в метрах;
# - расстояние до ближайшего аэропорта;
# - расстояние до ближайшего парка;
# - день и месяц публикации объявления.

# %% [markdown]
# #### Общая площадь

# %%
sns.histplot(data=data2['total_area'], bins=100)
plt.ylabel('кол-во объявлений')
plt.xlabel('площадь объекта')
plt.title('распределение объектов по общей площади');

# %% [markdown]
# Для наглядности сократим диапазон, исключив квартиры c аномально большой площадью.

# %%
sns.histplot(data=data2['total_area'], bins=100)
plt.ylabel('кол-во объявлений')
plt.xlabel('общая площадь объекта')
plt.xlim(0,300)
plt.title('распределение объектов по общей площади');

# %% [markdown]
# **Вывод:**
# Чаще всего встречаются квартиры общей площадью около 30 кв.м и 55 кв.м.

# %% [markdown]
# #### Жилая площадь

# %%
sns.histplot(data=data2['living_area'], bins=100)
plt.ylabel('кол-во объявлений')
plt.xlabel('жилая площадь объекта')
plt.title('распределение объектов по жилой площади');

# %% [markdown]
# Для наглядности сократим диапазон, исключив квартиры c аномально большой жилой площадью.

# %%
sns.histplot(data=data2['living_area'], bins=100)
plt.ylabel('кол-во объявлений')
plt.xlabel('жилая площадь объекта')
plt.xlim(0,200)
plt.title('распределение объектов по жилой площади');

# %% [markdown]
# **Вывод:**
# Чаще всего встречаются квартиры с жилой площадью около 15 кв.м и 30 кв.м.

# %% [markdown]
# #### Площадь кухни

# %%
sns.histplot(data=data2['kitchen_area'], bins=100)
plt.ylabel('кол-во объявлений')
plt.xlabel('площадь кухни')
plt.title('распределение объектов по площади кухни');

# %% [markdown]
# Для наглядности сократим диапазон, исключив квартиры c аномально большой площадью кухни.

# %%
sns.histplot(data=data2['kitchen_area'], bins=100)
plt.ylabel('кол-во объявлений')
plt.xlabel('площадь кухни')
plt.xlim(0,60)
plt.title('распределение объектов по площади кухни');

# %% [markdown]
# **Вывод:**
# Чаще всего встречаются квартиры с площадью кухни около 6,8 и 11 кв.м.

# %% [markdown]
# #### Высота потолоков

# %%
sns.histplot(data=data2['ceiling_height'], bins=100)
plt.ylabel('кол-во объявлений')
plt.xlabel('высота потолка')
plt.title('распределение объектов по высоте потолков');

# %% [markdown]
# Для наглядности сократим диапазон, исключив квартиры c аномально большой высотой потолков.

# %%
sns.histplot(data=data2['ceiling_height'], bins=100)
plt.ylabel('кол-во объявлений')
plt.xlabel('высота потолка')
plt.xlim(2,5)
plt.title('распределение объектов по высоте потолков');

# %% [markdown]
# **Вывод:**
# Чаще всего встречаются квартиры с высотой потолков 2.5 м.

# %% [markdown]
# #### Этаж

# %%
sns.histplot(data=data2['floor'], bins=100)
plt.ylabel('кол-во объявлений')
plt.xlabel('этаж')
plt.title('распределение объектов по этажу объекта');

# %% [markdown]
# **Вывод:** Чаще всего встречаются квартиры на 2 и 3 этажах.

# %% [markdown]
# #### Тип этажа (первый, последний, другой)

# %%
sns.histplot(data=data2['floor_type'], bins=3)
plt.ylabel('кол-во объявлений')
plt.xlabel('тип этажа')
plt.title('распределение объектов по типу этажа (первый, последний, другой)');

# %%
colors = sns.color_palette('pastel')[ 0:5 ]
plt.pie(x=data2['floor_type'].value_counts(), labels = data2['floor_type'].unique(),
            colors=colors, autopct='%.0f%%')
plt.title('распределение объектов по типу этажа (первый, последний, другой)')
plt.show()

# %% [markdown]
# **Вывод:**
# Примерно четверть всех квартир располагаются на первой или последних этажах.

# %% [markdown]
# #### Общее количество этажей в доме

# %%
sns.histplot(data=data2['floors_total'], bins=100)
plt.ylabel('кол-во объявлений')
plt.xlabel('этажность')
plt.title('распределение объектов по общему количеству этажей в доме');

# %% [markdown]
# **Вывод:**
# Чаще всего встречаются квартиры в 5-ти этажных и 9-эти этажных домах.

# %% [markdown]
# #### Расстояние до центра города в метрах

# %%
sns.histplot(data=data2['city_centers_nearest'], bins=100)
plt.ylabel('кол-во объявлений')
plt.xlabel('расстояние до центра, м')
plt.title('распределение объектов по расстоянию до центра города в метрах');

# %% [markdown]
# **Вывод:**
# Чаще всего встречаются квартиры на расстоянии примерно 15000 м от центра города.

# %% [markdown]
# #### Расстояние до ближайшего аэропорта

# %%
sns.histplot(data=data2['airports_nearest'], bins=100)
plt.ylabel('кол-во объявлений')
plt.xlabel('расстояние до ближайшего аэропорта, м')
plt.title('распределение объектов по расстоянию до ближайшего аэропорта');

# %% [markdown]
# **Вывод:**
# Чаще всего встречаются квартиры на расстоянии примерно 15000 м, 25000 м, 37000 м от ближайшего аэропорта.

# %% [markdown]
# #### Расстояние до ближайшего парка

# %%
sns.histplot(data=data2['parks_nearest'], bins=100)
plt.ylabel('кол-во объявлений')
plt.xlabel('расстояние до ближайшего парка, м')
plt.title('распределение объектов по расстоянию до ближайшего парка');

# %% [markdown]
# **Вывод:**
# Чаще всего встречаются квартиры на расстоянии примерно чуть больше 500 м до ближайшего парка.

# %% [markdown]
# #### День недели и месяц публикации объявления

# %%
sns.histplot(data=data2['day_of_week'], bins=7, binwidth=0.5)
plt.ylabel('кол-во объявлений')
plt.xlabel('день недели')
plt.xticks(range(0,7),['пн', "вт", "ср", "чт", "пт", "сб", "вс"])
plt.title('распределение объектов по дню недели публикации объявления');

# %%
sns.histplot(data=data2['first_day_exposition_month'], bins=12, binwidth=0.5)
plt.ylabel('кол-во объявлений')
plt.xlabel('месяц публикации объявления')
plt.title('распределение объектов по месяцу публикации объявления');

# %% [markdown]
# **Вывод**:
# Пользователи чаще публикуют объявления в будние дни.
# Пользователи чаще публикуют объявлений c февраля по март и с сентября по ноябрь.

# %% [markdown]
# ### 4.2. Изучим, как быстро продавались квартиры

# %%
sns.histplot(data=data2['days_exposition'], bins=100)
plt.ylabel('кол-во объявлений')
plt.xlabel('длительность размещения объявления, дни')
plt.title('сколько дней было размещено объявление (от публикации до снятия)');

# %% [markdown]
# Длительность объявлений свыше 400 дней — уже редки. Дольше 1000 дней объявлений минимальное количество. А на участке более 1200 дней гистограмма сливается с нулём.
# Выведем на экран гистограмму со значениями до 600 дней, чтобы ближе ознакомиться с наиболее частыми значениями.

# %%
sns.histplot(data=data2['days_exposition'], bins=200)
plt.ylabel('кол-во объявлений')
plt.xlabel('длительность размещения объявления, дни')
plt.xlim(0,600)
plt.title('сколько дней было размещено объявление (от публикации до снятия)');

# %% [markdown]
# На гистограмме заметны выбросы около 50 дней. Вероятно, что выбросы связаны с автоматическим снятием объявления агрегатором.
# Уточним, на каких именно днях эти выбросы.

# %%
data2['days_exposition'].value_counts()
# Out:
# 45.0      394
# 60.0      274
# 7.0       155
# 30.0      150
# 4.0       103
#          ...
# 631.0       1
# 803.0       1
# 1175.0      1
# 1076.0      1
# 1174.0      1
# Name: days_exposition, Length: 1033, dtype: int64

# %% [markdown]
# Аномалии содержат 45 и 60 дни.
# Ознакомимся с характерными значениями столбца, исключив аномалии.

# %%
data2.query('days_exposition != 45 and days_exposition != 60')['days_exposition'].describe()
# Out:
# count    11694.000000
# mean       192.693775
# std        229.990021
# min          1.000000
# 25%         44.000000
# 50%        106.000000
# 75%        252.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# **Вывод:**
# Медианное время продажи квартиры - 106 дней. Среднее значение - 192 день.
# 25% значений - менее 44 дней. Такие продажи считаются быстрыми.
# Другие 25% значений - 252 дней и более. Такие продажи считаются долгими.

# %% [markdown]
# ### 4.3. Далее изучим, какие факторы больше всего влияют на общую (полную) стоимость объекта:
# - общая площадь;
# - жилая площадь;
# - площадь кухни;
# - количество комнат;
# - этаж, на котором расположена квартира (первый, последний, другой);
# - дата размещения (день недели, месяц, год).

# %% [markdown]
# Выведем на экран матрицу корреляции между стоимостью объекта и параметрами площади (общая, жилая площадь, кухня).

# %%
pd.plotting.scatter_matrix(data2[['last_price', 'total_area', 'living_area', 'kitchen_area']], 
                           figsize=(8, 8));

# %% [markdown]
# **Вывод:** Все параметры площади положительно влияют на цену квартиры. При этом площадь кухни имеет чуть меньшее влияние на цену.

# %% [markdown]
# Выведем на экран график зависимости между стоимостью объекта и количеством комнат.

# %%
data2_pivot = data2.pivot_table(index='rooms', values='last_price', aggfunc='median')
data2_pivot['last_price'] = data2_pivot['last_price']/1000000

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(data=data2_pivot)
plt.grid()
plt.ylabel('медианная стоимость объекта, млн')
plt.xlabel('количество комнат')
plt.title('график зависимости между стоимостью объекта и количеством комнат');

# %%
data2.value_counts('rooms')
# Out:
# rooms
# 2     4843
# 1     4605
# 3     3768
# 4      778
# 5      209
# 0       81
# 6       63
# 7       34
# 9        6
# 8        5
# 10       3
# 11       2
# 14       1
# 16       1
# dtype: int64

# %% [markdown]
# **Вывод**: количество комнат положительно влияет на стоимость объекта. Данные показывают, что цена растёт до 7 комнат. После этого медианная стоимость не изменяется, и начинает увеличиваться только с 11 комнатам. Эти квартиры лишь единичные значения, которые не стоит учитывать для оценки корреляции.

# %% [markdown]
# Выведем на экран столбчатую диаграмму с медианными значениями стоимости объекта для каждого типа этажа.

# %%
data2_pivot_floor_type = data2.pivot_table(index='floor_type', values='last_price', aggfunc='median').reset_index()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(data=data2_pivot_floor_type, x='floor_type', y='last_price')
plt.grid()
plt.ylabel('медианная стоимость объекта, млн')
plt.xlabel('тип этажа')
plt.title('медианная стоимость объектов по типу этажа');

# %% [markdown]
# **Вывод**: наименьшая цена за квартиры на 1 этаже - 4 млн рублей. На последнем этаже медиана 4,5 млн рублей. Наконец, медианная цена квартиры, которые не находятся ни на первом, ни на последнем этажах - 5 млн рублей.
# Таким образом, выделенные нами типы этажа влияют на стоимость квартиры.

# %% [markdown]
# Выведем на экран столбчатые диаграммы с медианными значениями стоимости объекта по каждому дню недели, месяцу в году, году.

# %%
for i in [['day_of_week', 'дню недели'], 
          ['first_day_exposition_month', 'месяцу недели'], ['first_day_exposition_year', 'году недели']] :
    (
    data2
        .pivot_table(index=i[0], values='last_price', aggfunc='median')
        .plot(grid=True, figsize=(12, 5), kind='bar', title=f'Изменения стоимости объектов по {i[1]} публикации')
    )

# %% [markdown]
# **Вывод**:
# 1) день недели или месяц публикации объявления существенно не влияет на стоимость продажи квартиры. Медианная стоимость объектов в каждый день недели, месяц года практически близка к 5 млн рублей. При этом можно заметить тренд, что в пятницу и выходные значение медианной стоимости меньше, чем в другие дни. Что касается месяцев, то самые низкие значения имеют март и июнь.
# 2) Диаграмма медианной стоимости объектов с 2014 по 2019 годы показывает, что самая высокая стоимость продажи была в 2014 году - 8 млн рублей. В 2015 году медианная стоимость резко упала до 5,5 млн рублей и продолжала падение до 2017 года. В 2017-2018 годах стоимость закрепилась на отметке чуть больше 4,5 млн рублей. А в 2019 году выросла больше 5 млн рублей.

# %% [markdown]
# ### 4.4. Средняя цена одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Населённые пункты с самой высокой и низкой стоимостью квадратного метра.

# %% [markdown]
# Для начала определим нужные нам 10 населённых пунктов с наибольшим числом объявлений.

# %%
data2['locality_name'].value_counts().head(10)
# Out:
# Санкт-Петербург    10009
# Всеволожск           271
# Пушкин               234
# Мурино               228
# Шушары               217
# Колпино              203
# Кудрово              194
# Гатчина              149
# Петергоф             145
# Парголово            137
# Name: locality_name, dtype: int64

# %% [markdown]
# 1) Составим датасет только с объектами из этих населённых пунктов;
# 2) Построим сводную таблицу со средней ценой квадратного метра в этих населённых пунктах, используя созданный нами столбец price_per_m с ценой квадратного метра.

# %%
top10_cities = ['Санкт-Петербург', 'Всеволожск', 'Пушкин', 'поселок Шушары', 'поселок Мурино', 'Колпино', 'Гатчина', 'Петергоф', 'поселок Парголово', 'Сестрорецк']
data2_top10_cities = data2.query('locality_name in @top10_cities')

# %%
data2_top10_cities.pivot_table(index='locality_name', values='price_per_m').sort_values(by='price_per_m', ascending=False)
# Out:
#                    price_per_m
# locality_name
# Санкт-Петербург  113037.390586
# Пушкин           103920.487863
# Сестрорецк       102267.327209
# Петергоф          85554.144690
# Колпино           75938.525517
# Гатчина           69992.693356
# Всеволожск        67434.629963

# %% [markdown]
# **Вывод:**
# Самая высокая средняя цена квадратного метра - в Санкт-Петербурге, 114412 рублей.
# Самая низкая средняя цена квадратного метра - во Всеволожске, 67435 рублей.

# %% [markdown]
# ### 4.5. Средняя цена каждого километра от центра города в Санкт-Петербурге.

# %% [markdown]
# Для решения задачи выполним следующие шаги:
# 1) Составим сводную таблицу со средними значениями полной цены квартиры и цены квадратного метра в Санкт-Петербурге по каждому километру от центра;
# 2) Построим график, отображающий среднюю стоимость полной цены квартиры для каждого километра от центра;
# 3) Построим график, отображающий среднюю стоимость квадратного метра для каждого километра от центра.

# %%
data2_spb_centers_avg = data2.query('locality_name == "Санкт-Петербург"')\
.pivot_table(index = 'city_centers_nearest_km', values=['last_price', 'price_per_m'])
data2_spb_centers_avg['last_price_k'] = round(data2_spb_centers_avg['last_price'] / 1000)
data2_spb_centers_avg
# Out:
#                            last_price    price_per_m  last_price_k
# city_centers_nearest_km
# 0.0                      1.858112e+07  178256.049412       18581.0
# 1.0                      1.345129e+07  149376.116825       13451.0
# 2.0                      1.264202e+07  139888.975588       12642.0
# 3.0                      1.036010e+07  117936.028814       10360.0
# 4.0                      1.169000e+07  128872.009196       11690.0
# 5.0                      1.185462e+07  134870.521155       11855.0
# 6.0                      1.219702e+07  138730.601170       12197.0
# 7.0                      1.074856e+07  138229.816761       10749.0
# 8.0                      9.675233e+06  126160.228618        9675.0
# 9.0                      7.406132e+06  116696.858875        7406.0
# 10.0                     6.879417e+06  115528.124271        6879.0
# 11.0                     6.292027e+06  108562.440741        6292.0
# 12.0                     5.987223e+06  108561.505010        5987.0
# 13.0                     6.203941e+06  108353.870584        6204.0
# 14.0                     5.632615e+06  104258.658078        5633.0
# 15.0                     5.962514e+06  105099.675782        5963.0
# 16.0                     5.426578e+06  101058.423840        5427.0
# 17.0                     5.382512e+06   97574.116849        5383.0
# 18.0                     4.894926e+06   95225.363264        4895.0
# 19.0                     4.987383e+06   96668.321031        4987.0
# 20.0                     5.456400e+06  102955.374000        5456.0
# 21.0                     5.809508e+06   97993.856883        5810.0
# 22.0                     5.464979e+06   91597.158942        5465.0
# 23.0                     5.138915e+06   95806.370508        5139.0
# 24.0                     4.648000e+06   90830.670000        4648.0
# 25.0                     4.267500e+06   87803.487500        4268.0
# 26.0                     4.162600e+06   85062.060667        4163.0
# 27.0                     1.435000e+07  193918.920000       14350.0
# 28.0                     7.600000e+06   68468.470000        7600.0
# 29.0                     4.114000e+06   71898.876000        4114.0

# %%
data2_spb_centers_avg.plot(y='last_price_k', kind='bar', title='Санкт-Петербург')
plt.xlabel('расстояние до центра')
plt.ylabel('полная стоимость объекта (тыс. руб.)')
plt.show()

# %%
data2_spb_centers_avg.plot(y='price_per_m', kind='bar', title='Санкт-Петербург')
plt.xlabel('расстояние до центра')
plt.ylabel('стоимость кв. м (руб.)')
plt.show()

# %% [markdown]
# **Вывод:**
# Самые дорогие квартиры находятся в самом центре Санкт-Петербурга. Средняя стоимость квартир примерно 22 млн рублей, а стоимость квадратного метра около 190 тыс. рублей.
# Примечательно, что примерно такой же показатель средней цены квадратного метра у квартир, находящихся в 27 км от центра. Однако средняя общая стоимость не превышает 15 млн рублей.
# Самые низкие значения по полной стоимости объекта имеют квартиры на расстоянии с 9 по 26 км и 29 км от центра.
# Самые низкие значения по цене квадратного метра имеют квартиры на расстоянии с 17 по 19 км, 22 км, с 24 по 27 км и с 28 по 29 км.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# **Основные тренды и характеристики:**
# Основную долю рынка квартир в Санкт-Петербурге и ближайших населённых пунктах составляют квартиры со следующими параметрами:
# - общая площадь 30 и 55 кв. м.;
# - высота потолков - 2.5 м;
# - 3 или 4 этаж;
# - 5-эти этажный и 9-ти этажный дом;
# - 15 км от центра города.

# %% [markdown]
# **Продажа квартир и объявления:**
# - продажа квартиры быстре 44 дней считается быстрой;
# - продажа квартиры дольше 252 дней считается долгой.
#
# Чаще всего объявления появляются в будние дни, а также в первые и последние месяцы года.

# %% [markdown]
# **Что влияет на цену квартиры?**
# Следующие параметры увеличивают рыночную стоимость квартиры:
# 1. Общая площадь;
# 2. Расположение не на первом и не на последнем этаже;
# 3. Количество комнат.

# %% [markdown]
# **Самые дорогие и самые дешевые населенные пункты:**  Среди топ-10 населенных пунктов по количеству объявлений самая дорогая цена за кв. м в Санкт-Петербурге, Пушкине и Сестрорецке. Самые дешевые квартиры в Гатчине и во Всеволожске.

# %% [markdown]
#
# **Санкт-Петербург:** Самые дорогие квартиры Санкт-Петербурга находятся в 7 км от центра Санкт-Петербурга: цена квартир от 10 млн рублей и более, цена кв. м примерно от 120 тыс. рублей. Цена квартир в большей дальности от центра не превышает 10 млн рублей и средняя цена равно примерно 5 млн рублей, за исключением квартир на расстоянии от 27 км: на этом расстоянии средняя общая цена и цена кв. м примерно как у квартир в самом центре города.
